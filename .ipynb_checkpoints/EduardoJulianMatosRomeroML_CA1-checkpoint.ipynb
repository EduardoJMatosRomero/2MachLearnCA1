# %% [markdown]
# In the retail sector, it is possible to unlock insights to win and retain customers, drive business efficiencies, and ultimately improve purchases and customer interest. Retail organizations are using advanced analysis to understand their customers, improve forecasting, and achieve better, faster results. As a company's resources are limited, it is crucial to identify and target customers to secure their loyalty, enhance business efficiency, and ultimately improve performance.

# %% [markdown]
# You have been given access to a dataset containing customer transactions for an online retailer and tasked with using your machine learning tools to gain and report on business insights. The audience for this report are non-specialists.  In particular, your tasks are:
#
# Clustering
# Apply and evaluate various clustering techniques with the aim of generating actionable insights from the data.
#
# ●	Select and justify the features you will be using.
#
# ●	Apply appropriate clustering algorithms to the dataset.
#
# ●	Evaluate the performance of the algorithms and make a recommendation as to which gives the “best” results.
#
# ●	Include in your report your own interpretation of the results.
#
# Market Basket Analysis
# Perform a market basket analysis of the transaction data.
#
# ●	Include in your report a comparison and evaluation of at least two algorithms.
#
# ●	Include in your report your own interpretation of the results.

# %% [markdown]
# # Introduction
#
# The analysis focuses on clustering regularly purchased products to identify patterns and gain insights into consumer buying behaviour. This approach facilitates a better understanding of the dynamics of everyday purchases, enabling more targeted marketing strategies.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import scale
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

# %%
df = pd.read_excel("data.xlsx")
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month

# Display the DataFrame with new columns
print(df[['InvoiceDate', 'Year', 'Month']].head())
# Out:
#           InvoiceDate  Year  Month
# 0 2009-12-01 07:45:00  2009     12
# 1 2009-12-01 07:45:00  2009     12
# 2 2009-12-01 07:45:00  2009     12
# 3 2009-12-01 07:45:00  2009     12
# 4 2009-12-01 07:45:00  2009     12

# %% [markdown]
# Note
#
# It was decided to split 'InvoiceDate' into 'Year', 'Month', from the beginning to make future analysis easier.

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df = df.set_index('InvoiceDate')

# %% [markdown]
# Note
#
# To improve readability, we have set the 'InvoiceDate' column as the index of the dataset.
# This guarantees that each row is unique, eliminating the need for the default numerical index.

# %%
df.describe()
# Out:
#             Quantity          Price    Customer ID           Year  \
# count  525461.000000  525461.000000  417534.000000  525461.000000
# mean       10.337667       4.688834   15360.645478    2009.913927
# std       107.424110     146.126914    1680.811316       0.280472
# min     -9600.000000  -53594.360000   12346.000000    2009.000000
# 25%         1.000000       1.250000   13983.000000    2010.000000
# 50%         3.000000       2.100000   15311.000000    2010.000000
# 75%        10.000000       4.210000   16799.000000    2010.000000
# max     19152.000000   25111.090000   18287.000000    2010.000000
#
#                Month
# count  525461.000000
# mean        7.438630
# std         3.543294
# min         1.000000
# 25%         4.000000
# 50%         8.000000
# 75%        11.000000
# max        12.000000

# %% [markdown]
# Note
#
# An analysis using the .describe() method reveals several noteworthy observations:
#
# - The majority of transactions involve quantities ranging from 3 to 10 items, with most items priced at £5 or less.
#
# - Negative quantities and prices are present, and some records lack CustomerID data. The majority of transactions involve quantities ranging from 3 to 10 items, with most items priced at £5 or less.
#
# - The majority of transactions involve quantities ranging from 3 to 10 items, with most items priced at £5 or less. Additionally, there are several significant outliers that require further attention.

# %%
df.shape
# Out:
# (525461, 9)

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 525461 entries, 2009-12-01 07:45:00 to 2010-12-09 20:01:00
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   Price        525461 non-null  float64
#  5   Customer ID  417534 non-null  float64
#  6   Country      525461 non-null  object
#  7   Year         525461 non-null  int64
#  8   Month        525461 non-null  int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 40.1+ MB

# %%
def to_camel_case(s):
    # Split the string into words
    words = s.replace('_', ' ').split()
    # Convert the first word to lowercase and capitalize the initials of the remaining words
    camel_case_str = words[0].lower() + ''.join(word.capitalize() for word in words[1:])
    return camel_case_str

df.columns = [to_camel_case(col) for col in df.columns]

print(df.columns)
# Out:
# Index(['invoice', 'stockcode', 'description', 'quantity', 'price',
#        'customerId', 'country', 'year', 'month'],
#       dtype='object')

# %%
df.dtypes
# Out:
# invoice         object
# stockcode       object
# description     object
# quantity         int64
# price          float64
# customerId     float64
# country         object
# year             int64
# month            int64
# dtype: object

# %%
# # To prevent errors, converting 'Description','Invoice' and 'StockCode' to a string.
# df['Description'] = df['Description'].astype(str)
# df['Invoice'] = df['Invoice'].astype(str)
# df['StockCode'] = df['StockCode'].astype(str)

# %%
df.describe()
# Out:
#             quantity          price     customerId           year  \
# count  525461.000000  525461.000000  417534.000000  525461.000000
# mean       10.337667       4.688834   15360.645478    2009.913927
# std       107.424110     146.126914    1680.811316       0.280472
# min     -9600.000000  -53594.360000   12346.000000    2009.000000
# 25%         1.000000       1.250000   13983.000000    2010.000000
# 50%         3.000000       2.100000   15311.000000    2010.000000
# 75%        10.000000       4.210000   16799.000000    2010.000000
# max     19152.000000   25111.090000   18287.000000    2010.000000
#
#                month
# count  525461.000000
# mean        7.438630
# std         3.543294
# min         1.000000
# 25%         4.000000
# 50%         8.000000
# 75%        11.000000
# max        12.000000

# %%
df.country.nunique()
# Out:
# 40

# %%
df.country.unique()
# Out:
# array(['United Kingdom', 'France', 'USA', 'Belgium', 'Australia', 'EIRE',
#        'Germany', 'Portugal', 'Japan', 'Denmark', 'Nigeria',
#        'Netherlands', 'Poland', 'Spain', 'Channel Islands', 'Italy',
#        'Cyprus', 'Greece', 'Norway', 'Austria', 'Sweden',
#        'United Arab Emirates', 'Finland', 'Switzerland', 'Unspecified',
#        'Malta', 'Bahrain', 'RSA', 'Bermuda', 'Hong Kong', 'Singapore',
#        'Thailand', 'Israel', 'Lithuania', 'West Indies', 'Lebanon',
#        'Korea', 'Brazil', 'Canada', 'Iceland'], dtype=object)

# %%
customer_country=df[['country','customerId']]
customer_country.groupby(['country'])['customerId'].aggregate('count').reset_index().sort_values('customerId', ascending=False).head()
# Out:
#            country  customerId
# 37  United Kingdom      379423
# 10            EIRE        8710
# 13         Germany        8129
# 12          France        5710
# 24     Netherlands        2769

# %%
pd.DataFrame(df.nunique())
# Out:
#                  0
# invoice      28816
# stockcode     4632
# description   4681
# quantity       825
# price         1606
# customerId    4383
# country         40
# year             2
# month           12

# %%
for column in df.columns:
    # Checking if any value in the column is duplicated
    has_duplicates = df[column].duplicated().any()
    print(f'{column} has duplicates: {has_duplicates}')
# Out:
# invoice has duplicates: True
# stockcode has duplicates: True
# description has duplicates: True
# quantity has duplicates: True
# price has duplicates: True
# customerId has duplicates: True
# country has duplicates: True
# year has duplicates: True
# month has duplicates: True

# %% [markdown]
# ## Null Values

# %%
df.isnull().sum(axis=0)
# Out:
# invoice             0
# stockcode           0
# description      2928
# quantity            0
# price               0
# customerId     107927
# country             0
# year                0
# month               0
# dtype: int64

# %%
df['description'].tail(20)
# Out:
# InvoiceDate
# 2010-12-09 20:01:00            HOT WATER BOTTLE BABUSHKA
# 2010-12-09 20:01:00       HAND OVER THE CHOCOLATE   SIGN
# 2010-12-09 20:01:00               DINOSAURS  WRITING SET
# 2010-12-09 20:01:00                   SKULLS WRITING SET
# 2010-12-09 20:01:00       RECIPE BOX PANTRY YELLOW DESIGN
# 2010-12-09 20:01:00           ANGEL DECORATION 3 BUTTONS
# 2010-12-09 20:01:00                      KINGS CHOICE MUG
# 2010-12-09 20:01:00                   SAVE THE PLANET MUG
# 2010-12-09 20:01:00                   HOME SWEET HOME MUG
# 2010-12-09 20:01:00            POPPY'S PLAYHOUSE BATHROOM
# 2010-12-09 20:01:00             POPPY'S PLAYHOUSE KITCHEN
# 2010-12-09 20:01:00            POPPY'S PLAYHOUSE BEDROOM
# 2010-12-09 20:01:00       CLOTHES PEGS RETROSPOT PACK 24
# 2010-12-09 20:01:00          RED SPOT CERAMIC DRAWER KNOB
# 2010-12-09 20:01:00      PINK BLUE FELT CRAFT TRINKET BOX
# 2010-12-09 20:01:00                  FELTCRAFT DOLL ROSIE
# 2010-12-09 20:01:00          FELTCRAFT PRINCESS LOLA DOLL
# 2010-12-09 20:01:00        FELTCRAFT PRINCESS OLIVIA DOLL
# 2010-12-09 20:01:00    PINK FLORAL FELTCRAFT SHOULDER BAG
# 2010-12-09 20:01:00                JUMBO STORAGE BAG SUKI
# Name: description, dtype: object

# %%
df[df['description'].isnull()].tail()
# Out:
#                     invoice stockcode description  quantity  price  \
# InvoiceDate
# 2010-12-09 15:58:00  538141     22218         NaN         2    0.0
# 2010-12-09 15:58:00  538143    84534B         NaN         1    0.0
# 2010-12-09 17:17:00  538159     21324         NaN       -18    0.0
# 2010-12-09 17:17:00  538158     20892         NaN       -32    0.0
# 2010-12-09 17:18:00  538160     20956         NaN       288    0.0
#
#                      customerId         country  year  month
# InvoiceDate
# 2010-12-09 15:58:00         NaN  United Kingdom  2010     12
# 2010-12-09 15:58:00         NaN  United Kingdom  2010     12
# 2010-12-09 17:17:00         NaN  United Kingdom  2010     12
# 2010-12-09 17:17:00         NaN  United Kingdom  2010     12
# 2010-12-09 17:18:00         NaN  United Kingdom  2010     12

# %% [markdown]
# Note
#
# - The Price in these rows is 0, indicating that these orders did not generate any purchases.
#
# - At present, we can impute it with 'UNKNOWN ITEM' and address those later during the analysis.

# %% [markdown]
# ## Features Analysis

# %% [markdown]
# #### Analyzing "Description" feature

# %%
df['description'].value_counts().tail(20)
# Out:
# wet ctn                                1
# RUSSIAN FOLKART STACKING TINS          1
# correct previous adjustment            1
# SET OF 2 CHESTS CHOCOLAT AU LAIT       1
# HEART MEASURING SPOONS SMALL           1
# LARGE WHITE CHOCOLATE CANDLE           1
# missings                               1
# missing (wrongly coded?)               1
# BAG FOR CHILDREN VINTAGE BLUE          1
# Sold as 17003?                         1
# BAG FOR CHILDREN VINTAGE PINK          1
# BLUE OWL DECORATION                    1
# PINK OWL DECORATION                    1
# IVORY WALL CLOCK                       1
# RED WALL CLOCK                         1
# stock credited from royal yacht inc    1
# VINTAGE METAL CAKE STAND CREAM         1
# BLUE BAROQUE FLOCK CANDLE HOLDER       1
# S/4 HEART CRYSTAL FRIDGE MAGNETS       1
# dotcom email                           1
# Name: description, dtype: int64

# %%
df['description'].value_counts().head()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    3549
# REGENCY CAKESTAND 3 TIER              2212
# STRAWBERRY CERAMIC TRINKET BOX        1843
# PACK OF 72 RETRO SPOT CAKE CASES      1466
# ASSORTED COLOUR BIRD ORNAMENT         1457
# Name: description, dtype: int64

# %% [markdown]
# Note
#
# The code above shows that valid items are typically in uppercase, while non-valid or cancelled items are in lowercase.

# %% [markdown]
# #### Analyzing Invoice feature

# %%
df['invoice'].value_counts().tail(20)
# Out:
# C506476    1
# C491621    1
# C523991    1
# C491623    1
# C506489    1
# C506488    1
# C506485    1
# C506484    1
# C506483    1
# C506482    1
# C506481    1
# C506480    1
# C523975    1
# 523979     1
# C523978    1
# 523981     1
# 523984     1
# 523985     1
# C523988    1
# C516462    1
# Name: invoice, dtype: int64

# %%
df['invoice'].value_counts().head()
# Out:
# 537434    675
# 538071    652
# 537638    601
# 537237    597
# 536876    593
# Name: invoice, dtype: int64

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ## Removing Duplicates

# %%
customer_country=df[['country','customerId','invoice']].drop_duplicates()
customer_country.groupby(['country'])['customerId'].aggregate('count').reset_index().sort_values('customerId', ascending=False).head()
# Out:
#            country  customerId
# 37  United Kingdom       21481
# 13         Germany         513
# 10            EIRE         418
# 12          France         292
# 24     Netherlands         150

# %% [markdown]
# Note
#
# We will no longer track customers that appear to be duplicated, particularly when invoices for these customers are repeated in the same country.

# %% [markdown]
# ## Labelling Unknown Items

# %%
df['description'] = df['description'].fillna('UNKNOWN ITEM')
df.isnull().sum()
# Out:
# invoice             0
# stockcode           0
# description         0
# quantity            0
# price               0
# customerId     107927
# country             0
# year                0
# month               0
# dtype: int64

# %%
df['description'] = df['description'].fillna('UNKNOWN ITEM')
df.isnull().sum()
# Out:
# invoice             0
# stockcode           0
# description         0
# quantity            0
# price               0
# customerId     107927
# country             0
# year                0
# month               0
# dtype: int64

# %% [markdown]
# ## Removing Unidentified Customers.

# %%
df = df[pd.notnull(df['customerId'])]
df.isnull().sum(axis=0)
# Out:
# invoice        0
# stockcode      0
# description    0
# quantity       0
# price          0
# customerId     0
# country        0
# year           0
# month          0
# dtype: int64

# %% [markdown]
# ## Outliers

# %%
plt.figure(figsize=(18,6))
plt.scatter(x=df.index, y=df['price'])

# %%
Q1=df.quantile(.25)
Q3=df.quantile(.75)
IQR=Q3-Q1
print(IQR)
print("--------")
print(Q1)
print("--------")
print(Q3)

df=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]
# Out:
# quantity        10.0
# price            2.5
# customerId    2816.0
# year             0.0
# month            7.0
# dtype: float64
# --------
# quantity          2.00
# price             1.25
# customerId    13983.00
# year           2010.00
# month             4.00
# Name: 0.25, dtype: float64
# --------
# quantity         12.00
# price             3.75
# customerId    16799.00
# year           2010.00
# month            11.00
# Name: 0.75, dtype: float64
# C:\Users\eduma\AppData\Local\Temp/ipykernel_21556/3388604920.py:10: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
Q1_price = Q1['price'] 

# Filtering the dataset for products over 1.25 euros
high_value_purchases = df[df['price'] > Q1_price]

# Getting unique customers who have made high-value purchases
unique_customers_high_value = high_value_purchases['customerId'].unique()

# Getting the total number of unique customers in the entire dataset
total_unique_customers = df['customerId'].unique()

# Calculating the percentage of customers who have purchased items over 3000 euros
percentage_high_value_customers = (len(unique_customers_high_value) / len(total_unique_customers)) * 100

# Displaying the percentage
print(f'Percentage of customers who have purchased items over 1.25 euros: {percentage_high_value_customers:.2f}%')
# Out:
# Percentage of customers who have purchased items over 1.25 euros: 98.94%

# %%
Q3_price = Q3['price'] 

# Filtering the dataset for products over 2.55 euros
high_value_purchases = df[df['price'] > Q3_price]

# Getting unique customers who have made high-value purchases
unique_customers_high_value = high_value_purchases['customerId'].unique()

# Getting the total number of unique customers in the entire dataset
total_unique_customers = df['customerId'].unique()

# Calculating the percentage of customers who have purchased items over 3000 euros
percentage_high_value_customers = (len(unique_customers_high_value) / len(total_unique_customers)) * 100

# Displaying the percentage
print(f'Percentage of customers who have purchased items over 2.55 euros: {percentage_high_value_customers:.2f}%')
# Out:
# Percentage of customers who have purchased items over 2.55 euros: 88.01%

# %%
plt.figure(figsize=(18,6))
plt.scatter(x=df.index, y=df['price'])

# %%
df.describe()
# Out:
#             quantity          price     customerId      year          month
# count  328139.000000  328139.000000  328139.000000  328139.0  328139.000000
# mean        6.960398       2.348201   15381.361908    2010.0       7.018833
# std         6.722000       1.659662    1679.250358       0.0       3.356046
# min       -13.000000       0.000000   12346.000000    2010.0       1.000000
# 25%         2.000000       1.250000   14000.000000    2010.0       4.000000
# 50%         5.000000       1.950000   15358.000000    2010.0       7.000000
# 75%        12.000000       2.950000   16829.000000    2010.0      10.000000
# max        27.000000       7.500000   18287.000000    2010.0      12.000000

# %% [markdown]
# Note
#
# - To achieve a more precise clustering of products, we excluded products that cost over 7.5 € from our datasets. Our analysis aims to cluster regularly purchased products, and those over this price point are not considered in this case.

# %% [markdown]
# # Exploratory Data Analysis II

# %% [markdown]
# ## Do we Have Returns?

# %%
df[df['quantity'] < 0].head(20)
# Out:
#                      invoice stockcode                         description  \
# InvoiceDate
# 2010-01-04 09:43:00  C493411     21539             RETRO SPOTS BUTTER DISH
# 2010-01-04 10:41:00  C493426     22109        FULL ENGLISH BREAKFAST PLATE
# 2010-01-04 11:43:00  C493430     21556        CERAMIC STRAWBERRY MONEY BOX
# 2010-01-04 11:43:00  C493430     21232      STRAWBERRY CERAMIC TRINKET BOX
# 2010-01-04 11:43:00  C493430    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# 2010-01-04 11:46:00  C493431     21533           RETRO SPOT LARGE MILK JUG
# 2010-01-04 11:46:00  C493431     22066              LOVE HEART TRINKET POT
# 2010-01-04 11:46:00  C493431     21432      SET OF 3 CASES WOODLAND DESIGN
# 2010-01-04 13:30:00  C493440     21658                  GLASS  BEURRE DISH
# 2010-01-04 13:30:00  C493440     20914    SET/5 RED SPOTTY LID GLASS BOWLS
# 2010-01-04 13:35:00  C493441     21874                   GIN AND TONIC MUG
# 2010-01-04 14:00:00  C493445    84659A            WHITE TRAVEL ALARM CLOCK
# 2010-01-04 14:00:00  C493445     21314       SMALL GLASS HEART TRINKET POT
# 2010-01-04 14:00:00  C493445    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# 2010-01-04 14:00:00  C493445     21275      ZINC TOP  2 DOOR WOODEN SHELF
# 2010-01-04 15:25:00  C493535    84750B        BLACK SMALL GLASS CAKE STAND
# 2010-01-04 15:25:00  C493535    79191B            RETRO PLASTIC POLKA TRAY
# 2010-01-04 15:25:00  C493535    47503K           ASSORTED FLORAL SECATEURS
# 2010-01-04 15:25:00  C493535     20783           HEART EAR MUFF HEADPHONES
# 2010-01-04 15:25:00  C493535    35471A        SET OF 3 BIRD L.BLUE FEATHER
#
#                      quantity  price  customerId         country  year  month
# InvoiceDate
# 2010-01-04 09:43:00        -1   4.25     14590.0  United Kingdom  2010      1
# 2010-01-04 10:41:00        -1   3.39     16550.0  United Kingdom  2010      1
# 2010-01-04 11:43:00        -1   2.55     14680.0  United Kingdom  2010      1
# 2010-01-04 11:43:00        -2   1.25     14680.0  United Kingdom  2010      1
# 2010-01-04 11:43:00        -1   2.95     14680.0  United Kingdom  2010      1
# 2010-01-04 11:46:00        -1   4.95     17372.0  United Kingdom  2010      1
# 2010-01-04 11:46:00        -4   1.45     17372.0  United Kingdom  2010      1
# 2010-01-04 11:46:00        -1   5.95     17372.0  United Kingdom  2010      1
# 2010-01-04 13:30:00        -1   3.39     12709.0         Germany  2010      1
# 2010-01-04 13:30:00        -1   2.95     12709.0         Germany  2010      1
# 2010-01-04 13:35:00        -1   1.25     14156.0            EIRE  2010      1
# 2010-01-04 14:00:00        -1   2.55     16296.0  United Kingdom  2010      1
# 2010-01-04 14:00:00        -1   2.10     16296.0  United Kingdom  2010      1
# 2010-01-04 14:00:00        -2   2.95     16296.0  United Kingdom  2010      1
# 2010-01-04 14:00:00        -1   2.95     16296.0  United Kingdom  2010      1
# 2010-01-04 15:25:00        -1   1.95     17841.0  United Kingdom  2010      1
# 2010-01-04 15:25:00        -1   0.85     17841.0  United Kingdom  2010      1
# 2010-01-04 15:25:00        -1   1.95     17841.0  United Kingdom  2010      1
# 2010-01-04 15:25:00        -1   5.49     17841.0  United Kingdom  2010      1
# 2010-01-04 15:25:00        -1   1.25     17841.0  United Kingdom  2010      1

# %%
print(df['invoice'].isna().sum())
#The code is not working unless we instruct .str.startswith() to consider NA/NaN values as False
print(df[df['invoice'].str.startswith('C', na=False)].describe())
# Out:
# 0
#           quantity        price    customerId    year        month
# count  6038.000000  6038.000000   6038.000000  6038.0  6038.000000
# mean     -3.384068     3.005003  15064.346969  2010.0     6.472342
# std       3.378658     1.852635   1717.296528     0.0     3.327641
# min     -13.000000     0.120000  12346.000000  2010.0     1.000000
# 25%      -4.000000     1.450000  13564.000000  2010.0     4.000000
# 50%      -2.000000     2.550000  14934.000000  2010.0     6.000000
# 75%      -1.000000     4.250000  16554.000000  2010.0    10.000000
# max      -1.000000     7.500000  18286.000000  2010.0    12.000000

# %%
total_invoices = df['invoice'].notna().sum()  # Count non-NA invoice entries
invoices_starting_with_c = df['invoice'].str.startswith('C', na=False).sum()  # Count invoices starting with 'C'

# Data for plotting
sizes = [invoices_starting_with_c, total_invoices - invoices_starting_with_c]
labels = ['Invoices Starting with C', 'Other Invoices']

# Plotting the pie chart
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('Percentage of Invoices Returned')
plt.show()

# %%
invoices_starting_with_c = df[df['invoice'].str.startswith('C', na=False)].shape[0]
total_invoices = df['invoice'].notna().sum()
percentage_starting_with_c = (invoices_starting_with_c / total_invoices) * 100
print("Percentage of invoices starting with 'C': {:.2f}%".format(percentage_starting_with_c))
# Out:
# Percentage of invoices starting with 'C': 1.84%

# %% [markdown]
# Note
#
# Invoices beginning with the letter 'C' are designated as 'Canceling' or 'Returning' invoices.
#
# While a more in-depth analysis of these returns would be beneficial, for the sake of simplicity we will disregard them for now.

# %%
# Calculating total number of entries
total_entries = len(df)

# Counting number of entries where the invoice starts with 'C'
invoices_starting_with_c = df['invoice'].str.startswith('C', na=False).sum()

# Calculating the percentage
percentage_starting_with_c = (invoices_starting_with_c / total_entries) * 100

# Printing the result
print(f"Percentage of invoices starting with 'C': {percentage_starting_with_c:.2f}%")
# Out:
# Percentage of invoices starting with 'C': 1.84%

# %% [markdown]
# ## Removing Invoices Starting with 'C'.

# %% [markdown]
# As the number of invoices starting with the letter 'C' represents only 1.90% of the total dataset and is not part of the purpose of the analysis, it was decided to remove them.

# %%
df = df[~df['invoice'].str.startswith('C', na=False)]

# Now df does not contain rows where the invoice starts with 'C'
print("Rows with invoices starting with 'C' have been removed.")
print(f"Updated DataFrame shape: {df.shape}")
# Out:
# Rows with invoices starting with 'C' have been removed.
# Updated DataFrame shape: (322101, 9)

# %% [markdown]
# ## How Many Customers are Not Recurrent?

# %%
def unique_counts(df):
   for i in df.columns:
       count = df[i].nunique()
       print(i, ": ", count)
unique_counts(df)
# Out:
# invoice :  15847
# stockcode :  3534
# description :  3899
# quantity :  27
# price :  130
# customerId :  4032
# country :  37
# year :  1
# month :  12

# %% [markdown]
# ## What Items Were Purchased Less Frequently?

# %%
item_counts = df['description'].value_counts().sort_values(ascending=True).iloc[0:15]
plt.figure(figsize=(18,6))
sns.barplot(x=item_counts.index, y=item_counts.values, palette=sns.cubehelix_palette(15))
plt.ylabel("Counts")
plt.title("Which items were bought more often?");
plt.xticks(rotation=90);

# %%
item_counts
# Out:
# BAKING MOULD EASTER EGG MILK CHOC      1
# WOODEN ROUNDERS GARDEN SET             1
# PEN, 10 COLOURS - SPACEBOY             1
# MAGIC DRAWING SLATE FIDO               1
# TRAY FOR TV DINNER ,SPACEBOY           1
# BEECH WOOD P/FRAME                     1
# HANGING CHICK CREAM DECORATION         1
# NUMBER TILE VINTAGE FONT No            1
# ACRYLIC JEWEL ICICLE, BLUE             1
# SET OF 6 SPICE TINS PANTRY DESIGN      1
# HEN PARTY BANNER TAPE                  1
# PINK BITTY LIGHT CHAIN                 1
# MIDNIGHT BLUE CRYSTAL DROP EARRINGS    1
# CRACKED GLAZE NECKLACE RED             1
# NUMBER TILE COTTAGE GARDEN 1           1
# Name: description, dtype: int64

# %% [markdown]
# ##  Which Invoices Had the Highest Number of Items?

# %%
inv_counts = df['invoice'].value_counts().sort_values(ascending=False).iloc[0:15]
plt.figure(figsize=(18,6))
sns.barplot(x=inv_counts.index, y=inv_counts.values, palette=sns.color_palette("BuGn_d"))
plt.ylabel("Counts")
plt.title("Which invoices had the most items?");
plt.xticks(rotation=90);

# %% [markdown]
# ## What is the Country with The Highest Number of purchases?

# %%
info = pd.DataFrame(data = df.groupby(['country'])['invoice'].nunique(), index=df.groupby(['country']).groups.keys()).T
info
# Out:
#          Australia  Austria  Bahrain  Belgium  Brazil  Canada  \
# invoice         33       21        2       44       1       2
#
#          Channel Islands  Cyprus  Denmark  EIRE  ...  Singapore  Spain  \
# invoice               20      15       18   240  ...          4     45
#
#          Sweden  Switzerland  Thailand  USA  United Arab Emirates  \
# invoice      44           32         1   11                     5
#
#          United Kingdom  Unspecified  West Indies
# invoice           14593            8            1
#
# [1 rows x 37 columns]

# %%
plt.figure(figsize=(14,6))
plt.bar(list(df.groupby(['country']).groups.keys()), df.groupby(['country'])['customerId'].count())
plt.xticks(rotation = 90, fontsize = 14)
plt.title("Number of transanctions done for each country")
plt.ylabel("No. of trans.")
plt.xlabel("Country")
plt.show()

# %%
# Calculating the number of unique invoices per country
sales_per_country = df.groupby('country')['invoice'].nunique()

# Calculating the total number of sales transactions
total_sales = sales_per_country.sum()

# Calculating the percentage of total sales for each country
percent_sales = (sales_per_country / total_sales) * 100

# Sorting the percentages to find the countries with the smallest percent of sales
smallest_percent_sales = percent_sales.sort_values()

# Displaying the sorted percentages
print(smallest_percent_sales)
# Out:
# country
# West Indies              0.006310
# Thailand                 0.006310
# RSA                      0.006310
# Nigeria                  0.006310
# Brazil                   0.006310
# Malta                    0.012621
# Israel                   0.012621
# Iceland                  0.012621
# Korea                    0.012621
# Bahrain                  0.012621
# Canada                   0.012621
# Singapore                0.025241
# United Arab Emirates     0.031552
# Lithuania                0.031552
# Norway                   0.050483
# Unspecified              0.050483
# Poland                   0.056793
# USA                      0.069414
# Greece                   0.075724
# Finland                  0.075724
# Cyprus                   0.094655
# Japan                    0.094655
# Denmark                  0.113586
# Channel Islands          0.126207
# Austria                  0.132517
# Italy                    0.145138
# Switzerland              0.201931
# Australia                0.208241
# Portugal                 0.227172
# Belgium                  0.277655
# Sweden                   0.277655
# Spain                    0.283965
# Netherlands              0.555310
# France                   1.268379
# EIRE                     1.514482
# Germany                  1.817379
# United Kingdom          92.086830
# Name: invoice, dtype: float64

# %%
# Filtering for countries with 1% or less in purchases
countries_with_one_percent_or_less = percent_sales[percent_sales <= 1]

# Counting the number of countries meeting the criterion
number_of_countries = countries_with_one_percent_or_less.count()

# Display the count
print(f'Number of countries with 1% or less in purchases: {number_of_countries}')

# Displaying the names of these countries
print("Countries with 1% or less in purchases:")
print(countries_with_one_percent_or_less.index.tolist())
# Out:
# Number of countries with 1% or less in purchases: 33
# Countries with 1% or less in purchases:
# ['Australia', 'Austria', 'Bahrain', 'Belgium', 'Brazil', 'Canada', 'Channel Islands', 'Cyprus', 'Denmark', 'Finland', 'Greece', 'Iceland', 'Israel', 'Italy', 'Japan', 'Korea', 'Lithuania', 'Malta', 'Netherlands', 'Nigeria', 'Norway', 'Poland', 'Portugal', 'RSA', 'Singapore', 'Spain', 'Sweden', 'Switzerland', 'Thailand', 'USA', 'United Arab Emirates', 'Unspecified', 'West Indies']

# %% [markdown]
# Note
#
# - The UK conducted the majority of the transactions, with a total of 14593.
#
# - 'Australia', 'Austria', 'Bahrain', 'Belgium', 'Brazil', 'Canada', 'Channel Islands', 'Cyprus', 'Denmark', 'Finland', 'Greece', 'Iceland', 'Israel', 'Italy', 'Japan', 'Korea', 'Lithuania', 'Malta', 'Netherlands', 'Nigeria', 'Norway', 'Poland', 'Portugal', 'RSA', 'Singapore', 'Spain', 'Sweden', 'Switzerland', 'Thailand', 'USA', 'United Arab Emirates', 'Unspecified', 'West Indies' are countries with less than the 1% of purchases.

# %%
df2=df.groupby('invoice')[['quantity']].sum()

# %%
df2 = df2.reset_index()
df2.head()
# Out:
#    invoice  quantity
# 0   493410         5
# 1   493412         5
# 2   493414        52
# 3   493427       116
# 4   493428        82

# %%
df['invoicedate'] = df.index

# Merging df with df2 based on the invoice column using the 'left' join to retain all records from 'df' in the merged 
# DataFrame, while only the matching entries from 'df2' are included.

df = df.merge(df2, how='left', on='invoice')

# Changing the column names to clarify their meaning. 'quantity_x' has been replaced with 'product units' and 'quantityInv' with 'number of products invoiced in each invoice'.

df = df.rename(columns={'quantity_x' : 'quantity', 'quantity_y' : 'quantityInv'})
df.tail(10)
# Out:
#        invoice stockcode                         description  quantity  price  \
# 322091  538171     22748           POPPY'S PLAYHOUSE KITCHEN         2   2.10
# 322092  538171     22745          POPPY'S PLAYHOUSE BEDROOM          2   2.10
# 322093  538171     22558     CLOTHES PEGS RETROSPOT PACK 24          4   1.49
# 322094  538171     21671        RED SPOT CERAMIC DRAWER KNOB         6   1.25
# 322095  538171     20971    PINK BLUE FELT CRAFT TRINKET BOX         2   1.25
# 322096  538171     22271                FELTCRAFT DOLL ROSIE         2   2.95
# 322097  538171     22750        FELTCRAFT PRINCESS LOLA DOLL         1   3.75
# 322098  538171     22751      FELTCRAFT PRINCESS OLIVIA DOLL         1   3.75
# 322099  538171     20970  PINK FLORAL FELTCRAFT SHOULDER BAG         2   3.75
# 322100  538171     21931              JUMBO STORAGE BAG SUKI         2   1.95
#
#         customerId         country  year  month         invoicedate  \
# 322091     17530.0  United Kingdom  2010     12 2010-12-09 20:01:00
# 322092     17530.0  United Kingdom  2010     12 2010-12-09 20:01:00
# 322093     17530.0  United Kingdom  2010     12 2010-12-09 20:01:00
# 322094     17530.0  United Kingdom  2010     12 2010-12-09 20:01:00
# 322095     17530.0  United Kingdom  2010     12 2010-12-09 20:01:00
# 322096     17530.0  United Kingdom  2010     12 2010-12-09 20:01:00
# 322097     17530.0  United Kingdom  2010     12 2010-12-09 20:01:00
# 322098     17530.0  United Kingdom  2010     12 2010-12-09 20:01:00
# 322099     17530.0  United Kingdom  2010     12 2010-12-09 20:01:00
# 322100     17530.0  United Kingdom  2010     12 2010-12-09 20:01:00
#
#         quantityInv
# 322091          145
# 322092          145
# 322093          145
# 322094          145
# 322095          145
# 322096          145
# 322097          145
# 322098          145
# 322099          145
# 322100          145

# %%
df.describe()
# Out:
#             quantity          price     customerId      year          month  \
# count  322101.000000  322101.000000  322101.000000  322101.0  322101.000000
# mean        7.154312       2.335888   15387.304566    2010.0       7.029078
# std         6.616254       1.653344    1677.959851       0.0       3.355732
# min         1.000000       0.000000   12346.000000    2010.0       1.000000
# 25%         2.000000       1.250000   14016.000000    2010.0       4.000000
# 50%         5.000000       1.950000   15366.000000    2010.0       7.000000
# 75%        12.000000       2.950000   16841.000000    2010.0      10.000000
# max        27.000000       7.500000   18287.000000    2010.0      12.000000
#
#          quantityInv
# count  322101.000000
# mean      245.068978
# std       225.295630
# min         1.000000
# 25%       106.000000
# 50%       183.000000
# 75%       307.000000
# max      2589.000000

# %%
df['invoicedate'] = df['invoicedate'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
df.head()
# Out:
#   invoice stockcode                      description  quantity  price  \
# 0  493410   TEST001          This is a test product.         5   4.50
# 1  493412   TEST001          This is a test product.         5   4.50
# 2  493414     21533        RETRO SPOT LARGE MILK JUG        12   4.25
# 3  493414     37508  NEW ENGLAND CERAMIC CAKE SERVER         2   2.55
# 4  493414    35001G             HAND OPEN SHAPE GOLD         2   4.25
#
#    customerId         country  year  month          invoicedate  quantityInv
# 0     12346.0  United Kingdom  2010      1  2010-01-04 09:24:00            5
# 1     12346.0  United Kingdom  2010      1  2010-01-04 09:53:00            5
# 2     14590.0  United Kingdom  2010      1  2010-01-04 10:28:00           52
# 3     14590.0  United Kingdom  2010      1  2010-01-04 10:28:00           52
# 4     14590.0  United Kingdom  2010      1  2010-01-04 10:28:00           52

# %%
df.dtypes
# Out:
# invoice         object
# stockcode       object
# description     object
# quantity         int64
# price          float64
# customerId     float64
# country         object
# year             int64
# month            int64
# invoicedate     object
# quantityInv      int64
# dtype: object

# %% [markdown]
# ## What is The Revenue/Growth of The Company Through the Year?

# %%
df['invoicedate'] = pd.to_datetime(df['invoicedate'])

#creating YearMonth field for the ease of reporting and visualization
df['invoiceyearmonth'] = df['invoicedate'].dt.strftime('%Y-%m')

# Calculate revenue for each row
df['revenue'] = df['price'] * df['quantity']

# Group by the new 'invoiceyearmonth' and sum the revenue
df_revenue = df.groupby('invoiceyearmonth')['revenue'].sum().reset_index()

# Calculating monthly percentage change
df_revenue['monthlygrowth'] = df_revenue['revenue'].pct_change()

# %%
# Seting the figure size for better readability
plt.figure(figsize=(12, 6))  
plt.plot(df_revenue['invoiceyearmonth'], df_revenue['revenue'], marker='o')  # Plotting revenue over time
# Adding a title
plt.title('Monthly Revenue Over Time')  
# Labeling the x-axis
plt.xlabel('Year-Month') 
# Labeling the y-axis
plt.ylabel('Revenue')  
# Rotating date labels for better visibility
plt.xticks(rotation=45)  
# Adding a grid for easier reading
plt.grid(True)  
# Adjusting the layout to make room for the rotated date labels
plt.tight_layout()  
# Displaying the plot
plt.show()

# %% [markdown]
# Note
#
# As can be seen over 2010, the company had a steady turnover until August, since then and until November it experienced an exponential turnover, finally in December the turnover dropped drastically.

# %%
plt.figure(figsize=(10, 5))

# Plotting the monthly growth. Assuming the data goes up to November 2011 and excluding that from the plot.
mask = df_revenue['invoiceyearmonth'] < '201112'
plt.plot(df_revenue[mask]['invoiceyearmonth'], df_revenue[mask]['monthlygrowth'], marker='o', linestyle='-')

# Adding title and labels
plt.title('Monthly Growth Rate')
plt.xlabel('Year-Month')
plt.ylabel('Percentage Growth')

# Rotate date labels for better readability
plt.xticks(rotation=45)
plt.grid(True)

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Note
#
# As can be seen over the year as a whole, the company did not experience significant growth, although there was some growth in the first and last quarters of the year.

# %% [markdown]
# # Clustering Analysis
#
# - Recency - Customers are clustered based on their most recent purchase.
#
# - Frequency - Customers are clustered based on their purchase frequency within the company.
#
# - Revenue - Customers are clustered based on benefits generated for the company through their purchases.

# %% [markdown]
# ## Customer Segmentation by Purchase Frequency and Revenue Impact

# %%
df_uk = df.query("country=='United Kingdom'").reset_index(drop=True)

# %% [markdown]
# Note
#
# To perform an analysis with less bias, the clustering analysis will solely focus on the United Kingdom, as it accounts for the majority of the company's purchases. This is due to the potential variation in customer behaviour between countries.

# %% [markdown]
# ## Time Since Each Client's Largest Purchase

# %%
#geting the max purchase date for each customer and create a dataframe with it
df_uk_purchase = df_uk.groupby('customerId').invoicedate.max().reset_index()
df_uk_purchase.columns = ['customerId','maxpurchasedate']

#Taking observation points as the max invoice date in the dataset
df_uk_purchase['recency'] = (df_uk_purchase['maxpurchasedate'].max() - df_uk_purchase['maxpurchasedate']).dt.days

df_uk_purchase
# Out:
#       customerId     maxpurchasedate  recency
# 0        12346.0 2010-06-28 13:53:00      164
# 1        12608.0 2010-10-31 10:49:00       39
# 2        12745.0 2010-08-10 10:14:00      121
# 3        12746.0 2010-06-17 10:41:00      175
# 4        12747.0 2010-12-05 15:38:00        4
# ...          ...                 ...      ...
# 3711     18283.0 2010-11-22 15:30:00       17
# 3712     18284.0 2010-10-04 11:33:00       66
# 3713     18285.0 2010-02-17 10:24:00      295
# 3714     18286.0 2010-08-20 11:57:00      111
# 3715     18287.0 2010-11-22 11:51:00       17
#
# [3716 rows x 3 columns]

# %% [markdown]
# The analysis is determining the impact on revenue by considering the timing of customers' largest purchases in the past. It feature is being called 'recency'.
#
# - The dataset is grouping by 'customerid' and 'invoicedate' to track changes over time.

# %% [markdown]
# ## K-Means

# %%
# Creating a generic user dataframe to keep CustomerID and new segmentation scores
df_user = pd.DataFrame(df_uk['customerId'].unique())
df_user.columns = ['customerId']

# Merging this dataframe to our new user dataframe
df_user = pd.merge(df_user, df_uk_purchase[['customerId','recency']], on='customerId')

from sklearn.cluster import KMeans

sse={}
df_recency = df_user[['recency']]
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(df_recency)
    df_recency["clusters"] = kmeans.labels_
    sse[k] = kmeans.inertia_ 
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.show()

# %%
#building 4 clusters for recency and add it to dataframe
kmeans = KMeans(n_clusters=4)
kmeans.fit(df_user[['recency']])
df_user['recencyCluster_Kmeans'] = kmeans.predict(df_user[['recency']])

#function for ordering cluster numbers
def order_cluster(cluster_field_name, target_field_name,df,ascending):
    new_cluster_field_name = 'new_' + cluster_field_name
    df_new = df.groupby(cluster_field_name)[target_field_name].mean().reset_index()
    df_new = df_new.sort_values(by=target_field_name,ascending=ascending).reset_index(drop=True)
    df_new['index'] = df_new.index
    df_final = pd.merge(df,df_new[[cluster_field_name,'index']], on=cluster_field_name)
    df_final = df_final.drop([cluster_field_name],axis=1)
    df_final = df_final.rename(columns={"index":cluster_field_name})
    return df_final

df_user = order_cluster('recencyCluster_Kmeans', 'recency',df_user,False)

df_user
# Out:
#       customerId  recency  recencyCluster_Kmeans
# 0        12346.0      164                      1
# 1        17969.0      137                      1
# 2        14653.0      148                      1
# 3        13338.0      176                      1
# 4        15684.0      182                      1
# ...          ...      ...                    ...
# 3711     18043.0        1                      3
# 3712     18269.0        1                      3
# 3713     12942.0        0                      3
# 3714     13369.0        0                      3
# 3715     15211.0        0                      3
#
# [3716 rows x 3 columns]

# %% [markdown]
# ## DBSCAN

# %%
# Initialising an object neigh by calling a method NearestNeighbors()
neigh = NearestNeighbors(n_neighbors = 20)

# Training the model by calling a method fit()
nbrs = neigh.fit(df_user[['customerId','recency']])

# Storing the distance and indices into distances and indices arrays
distances, indices = nbrs.kneighbors(df_user[['customerId','recency']])

print(distances, indices)
# Out:
# [[  0.         290.29123307 400.15122142 ... 505.5422831  507.24353125
#   507.67016851]
#  [  0.          21.9317122   24.20743687 ...  70.60453243  72.20110802
#    72.9177619 ]
#  [  0.          11.66190379  19.10497317 ...  75.27283707  77.82673063
#    78.33900689]
#  ...
#  [  0.           9.43398113  12.20655562 ...  32.64965543  33.28663395
#    34.92849839]
#  [  0.           6.08276253  14.76482306 ...  49.49747468  49.64876635
#    50.        ]
#  [  0.          10.04987562  11.04536102 ...  35.22782991  40.85339643
#    41.86884283]] [[   0 3347  378 ...  922 3038 1145]
#  [   1  128  420 ...  426  954  328]
#  [   2  422   50 ...  609 1111 1030]
#  ...
#  [3713 3682 2740 ... 3448 2574 2678]
#  [3714 3694 3237 ... 2572 2039 2049]
#  [3715 2578 3645 ... 2444 2706 2187]]

# %%
# Plotting K-distance Graph
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.figure(figsize=(20,10))
plt.plot(distances)
plt.title('K-distance Graph',fontsize=20)
plt.xlabel('Data Points sorted by distance',fontsize=14)
plt.ylabel('Epsilon',fontsize=14)
plt.show()

# %%
# Initialise an object by calling a method DBSCAN along with parameters as eps and min_samples
dbscan_opt = DBSCAN(eps = 50, min_samples =6)

# Train the model by calling a method fit()
dbscan_opt.fit(df_user[['customerId','recency']])
# Out:
# DBSCAN(eps=50, min_samples=6)

# %%
# Add another column into the dataframe (df)
df_user['recencyCluster_DBSCAN'] = dbscan_opt.labels_

# Display the counts by labels
df_user['recencyCluster_DBSCAN'].value_counts()
df_user.head()
# Out:
#    customerId  recency  recencyCluster_Kmeans  recencyCluster_DBSCAN
# 0     12346.0      164                      1                     -1
# 1     17969.0      137                      1                      0
# 2     14653.0      148                      1                      0
# 3     13338.0      176                      1                      0
# 4     15684.0      182                      1                      1

# %%
max(dbscan_opt.labels_)
# Out:
# 7

# %%
df_user['recencyCluster_DBSCAN']=dbscan_opt.labels_
df_user['recencyCluster_DBSCAN'].value_counts()
# Out:
#  0    3540
# -1      99
#  2      17
#  1      14
#  6      11
#  4      11
#  5       9
#  3       8
#  7       7
# Name: recencyCluster_DBSCAN, dtype: int64

# %% [markdown]
# ## Frequency Each Client Purchase

# %%
#getting order counts for each user and create a dataframe with it
df_frequency = df_uk.groupby('customerId').invoicedate.count().reset_index()
df_frequency.columns = ['customerId','frequency']

#adding this data to our main dataframe
df_user = pd.merge(df_user, df_frequency, on='customerId')

df_user
# Out:
#       customerId  recency  recencyCluster_Kmeans  recencyCluster_DBSCAN  \
# 0        12346.0      164                      1                     -1
# 1        17969.0      137                      1                      0
# 2        14653.0      148                      1                      0
# 3        13338.0      176                      1                      0
# 4        15684.0      182                      1                      1
# ...          ...      ...                    ...                    ...
# 3711     18043.0        1                      3                      0
# 3712     18269.0        1                      3                      0
# 3713     12942.0        0                      3                      0
# 3714     13369.0        0                      3                      0
# 3715     15211.0        0                      3                      0
#
#       frequency
# 0            28
# 1           106
# 2           117
# 3            85
# 4             2
# ...         ...
# 3711         61
# 3712          7
# 3713         12
# 3714         11
# 3715         18
#
# [3716 rows x 5 columns]

# %% [markdown]
# ## K-Means

# %%
# k-means
kmeans = KMeans(n_clusters=4)
kmeans.fit(df_user[['frequency']])
df_user['frequencyCluster_Kmeans'] = kmeans.predict(df_user[['frequency']])

# ordering the frequency cluster
df_user = order_cluster('frequencyCluster_Kmeans', 'frequency',df_user,True)

# details of each cluster
df_user.groupby('frequencyCluster_Kmeans')['frequency'].describe()
# Out:
#                           count         mean         std     min      25%  \
# frequencyCluster_Kmeans
# 0                        3157.0    39.951220   33.372900     1.0    13.00
# 1                         494.0   230.186235   79.666405   136.0   165.25
# 2                          60.0   691.000000  245.971543   468.0   516.00
# 3                           5.0  2840.400000  883.682239  2166.0  2212.00
#
#                             50%      75%     max
# frequencyCluster_Kmeans
# 0                          30.0    59.00   135.0
# 1                         210.0   271.75   461.0
# 2                         604.5   719.50  1518.0
# 3                        2341.0  3294.00  4189.0

# %% [markdown]
# ## DBSCAN

# %%
# Initialising an object neigh by calling a method NearestNeighbors()
neigh = NearestNeighbors(n_neighbors = 20)

# Training the model by calling a method fit()
nbrs = neigh.fit(df_user[['customerId','frequency']])

# Storing the distance and indices into distances and indices arrays
distances, indices = nbrs.kneighbors(df_user[['customerId','frequency']])

print(distances, indices)
# Out:
# [[   0.          262.48809497  399.21172327 ...  497.78810753
#    498.2258524   501.        ]
#  [   0.           10.81665383   20.24845673 ...   59.61543424
#     62.16912417   63.28506933]
#  [   0.            3.60555128   17.4642492  ...   54.03702434
#     54.3783045    55.4436651 ]
#  ...
#  [   0.         1150.70847742 1169.2766995  ... 1747.46959916
#   1751.38402414 1755.88724012]
#  [   0.         1174.58801288 1290.69671108 ... 1972.26899788
#   1982.76675381 1995.48916309]
#  [   0.          732.06898582 1301.8129666  ... 1749.37274473
#   1752.00028539 1766.55625441]] [[   0 2795  875 ... 2214  829 2978]
#  [   1  544 2472 ... 2944 2454 3608]
#  [   2  810 1581 ... 3519   59 3621]
#  ...
#  [3713 3671 3651 ... 3321 3191 3708]
#  [3714 3663 3659 ... 3374 3358 3271]
#  [3715 3672 3713 ... 3701 3267 3458]]

# %%
# Plotting K-distance Graph
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.figure(figsize=(20,10))
plt.plot(distances)
plt.title('K-distance Graph',fontsize=20)
plt.xlabel('Data Points sorted by distance',fontsize=14)
plt.ylabel('Epsilon',fontsize=14)
plt.show()

# %%
# Initialise an object by calling a method DBSCAN along with parameters as eps and min_samples
dbscan_opt = DBSCAN(eps = 100, min_samples =6)

# Train the model by calling a method fit()
dbscan_opt.fit(df_user[['customerId','frequency']])
# Out:
# DBSCAN(eps=100, min_samples=6)

# %%
# Add another column into the dataframe (df)
df_user['frequencyCluster_DBSCAN'] = dbscan_opt.labels_

# Display the counts by labels
df_user['frequencyCluster_DBSCAN'].value_counts()
df_user.head()
# Out:
#    customerId  recency  recencyCluster_Kmeans  recencyCluster_DBSCAN  \
# 0     12346.0      164                      1                     -1
# 1     17969.0      137                      1                      0
# 2     14653.0      148                      1                      0
# 3     13338.0      176                      1                      0
# 4     15684.0      182                      1                      1
#
#    frequency  frequencyCluster_Kmeans  frequencyCluster_DBSCAN
# 0         28                        0                       -1
# 1        106                        0                        0
# 2        117                        0                        0
# 3         85                        0                        0
# 4          2                        0                        0

# %%
max(dbscan_opt.labels_)
# Out:
# 2

# %%
df_user['frequencyCluster_DBSCAN']=dbscan_opt.labels_
df_user['frequencyCluster_DBSCAN'].value_counts()
# Out:
#  0    3619
# -1      81
#  1       9
#  2       7
# Name: frequencyCluster_DBSCAN, dtype: int64

# %% [markdown]
# ## Revenue the company makes by product

# %%
#calculating revenue for each customer
df_user['revenue'] = df['price'] * df['quantityInv']
df_revenue = df_user.groupby('customerId').revenue.sum().reset_index()

#merging it with our main dataframe
df_user = pd.merge(df_user, df_revenue, on='customerId')

# %%
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3716 entries, 0 to 3715
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customerId               3716 non-null   float64
#  1   recency                  3716 non-null   int64
#  2   recencyCluster_Kmeans    3716 non-null   int64
#  3   recencyCluster_DBSCAN    3716 non-null   int64
#  4   frequency                3716 non-null   int64
#  5   frequencyCluster_Kmeans  3716 non-null   int64
#  6   frequencyCluster_DBSCAN  3716 non-null   int64
#  7   revenue_x                3716 non-null   float64
#  8   revenue_y                3716 non-null   float64
# dtypes: float64(3), int64(6)
# memory usage: 290.3 KB

# %% [markdown]
# ## K-Means

# %%
#applying clustering
kmeans = KMeans(n_clusters=4)
kmeans.fit(df_user[['revenue_x']])
df_user['revenueCluster_Kmeans'] = kmeans.predict(df_user[['revenue_x']])


#ordering the cluster numbers
df_user = order_cluster('revenueCluster_Kmeans', 'revenue_x',df_user,True)

#showing details of the dataframe
df_user.groupby('revenueCluster_Kmeans')['revenue_x'].describe()
# Out:
#                         count          mean          std      min       25%  \
# revenueCluster_Kmeans
# 0                      3124.0    377.942414   269.361614     0.00    161.25
# 1                       509.0   1863.474440   654.108480  1118.60   1331.25
# 2                        59.0   5229.215254  1159.702288  3583.80   4252.50
# 3                        24.0  10833.750000  1349.853253  8606.25  10023.75
#
#                             50%       75%       max
# revenueCluster_Kmeans
# 0                        300.90    539.70   1113.75
# 1                       1721.25   2286.90   3422.25
# 2                       5163.75   5973.75   7593.75
# 3                      10023.75  12048.75  13668.75

# %% [markdown]
# ## DBSCAN

# %%
# Initialising an object neigh by calling a method NearestNeighbors()
neigh = NearestNeighbors(n_neighbors = 20)

# Training the model by calling a method fit()
nbrs = neigh.fit(df_user[['customerId','revenue_x']])

# Storing the distance and indices into distances and indices arrays
distances, indices = nbrs.kneighbors(df_user[['customerId','revenue_x']])

print(distances, indices)
# Out:
# [[   0.          400.0002      402.20692436 ...  535.25901207
#    544.32900208  545.27063235]
#  [   0.           25.03517525   36.22299822 ...   83.60659364
#     83.67125193   87.4082948 ]
#  [   0.            9.3542771    34.14103103 ...   69.08871109
#     72.43661022   72.88545808]
#  ...
#  [   0.           76.          111.         ... 2486.35823042
#   3088.93978575 3679.        ]
#  [   0.          638.          646.         ... 4033.61326852
#   4138.29747602 4307.        ]
#  [   0.           70.          635.         ... 2913.01235837
#   3034.         3091.52405781]] [[   0  344 3122 ... 1333  774  915]
#  [   1 2305  381 ...  428 2516  805]
#  [   2  681   33 ...  608 1068 1555]
#  ...
#  [3713 3704 3705 ... 3711 3658 3702]
#  [3714 3696 3709 ... 3693 3702 3706]
#  [3715 3695 3696 ... 3693 3706 3702]]

# %%
# Plotting K-distance Graph
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.figure(figsize=(20,10))
plt.plot(distances)
plt.title('K-distance Graph',fontsize=20)
plt.xlabel('Data Points sorted by distance',fontsize=14)
plt.ylabel('Epsilon',fontsize=14)
plt.show()

# %%
# Initialise an object by calling a method DBSCAN along with parameters as eps and min_samples
dbscan_opt = DBSCAN(eps = 100, min_samples =6)

# Train the model by calling a method fit()
dbscan_opt.fit(df_user[['customerId','revenue_x']])
# Out:
# DBSCAN(eps=100, min_samples=6)

# %%
# Add another column into the dataframe (df)
df_user['revenueCluster_DBSCAN'] = dbscan_opt.labels_

# Display the counts by labels
df_user['revenueCluster_DBSCAN'].value_counts()
df_user.head()
# Out:
#    customerId  recency  recencyCluster_Kmeans  recencyCluster_DBSCAN  \
# 0     12346.0      164                      1                     -1
# 1     17969.0      137                      1                      0
# 2     14653.0      148                      1                      0
# 3     13338.0      176                      1                      0
# 4     15684.0      182                      1                      1
#
#    frequency  frequencyCluster_Kmeans  frequencyCluster_DBSCAN  revenue_x  \
# 0         28                        0                       -1       22.5
# 1        106                        0                        0       22.5
# 2        117                        0                        0      221.0
# 3         85                        0                        0      132.6
# 4          2                        0                        0      221.0
#
#    revenue_y  revenueCluster_Kmeans  revenueCluster_DBSCAN
# 0       22.5                      0                     -1
# 1       22.5                      0                      0
# 2      221.0                      0                      0
# 3      132.6                      0                      0
# 4      221.0                      0                      0

# %%
#ordering the cluster numbers
df_user = order_cluster('revenueCluster_DBSCAN', 'revenue_x',df_user,True)

#showing details of the dataframe
df_user.groupby('revenueCluster_DBSCAN')['revenue_x'].describe()
# Out:
#                         count         mean          std      min        25%  \
# revenueCluster_DBSCAN
# 0                      3069.0   367.402379   259.374142     0.00   159.8000
# 1                         6.0   844.983333    41.274140   791.35   821.0625
# 2                         8.0  1006.037500    64.979254   914.50   961.2750
# 3                        10.0  1054.530000    49.580654   990.00  1019.7000
# 4                         9.0  1081.694444    52.368457   981.75  1065.0000
# 5                         6.0  1099.333333    53.909106  1020.50  1070.6250
# 6                         7.0  1111.500000    53.619143  1023.40  1089.8750
# 7                         6.0  1116.275000    50.789170  1071.00  1087.8750
# 8                         6.0  1126.225000    45.622437  1039.50  1127.0250
# 9                        14.0  1134.417857    63.580203  1020.50  1098.8750
# 10                        7.0  1143.535714    29.493583  1097.40  1125.0000
# 11                        6.0  1153.958333    35.399681  1112.15  1136.3000
# 12                        5.0  1218.150000    19.157766  1195.05  1205.1000
# 13                        8.0  1295.143750    47.182483  1215.40  1275.7500
# 14                        9.0  1380.105556    55.570599  1317.50  1327.5000
# 15                        6.0  1537.400000    50.775132  1494.90  1498.8375
# 16                        6.0  1722.633333    31.211643  1674.00  1721.2500
# 17                      528.0  2707.770341  2197.744219    22.50  1484.1375
#
#                             50%        75%       max
# revenueCluster_DBSCAN
# 0                       295.350   522.7500   1232.50
# 1                       850.500   854.2500    910.80
# 2                       999.600  1049.5375   1093.95
# 3                      1035.150  1090.6875   1136.45
# 4                      1086.250  1123.9500   1148.40
# 5                      1100.625  1130.6250   1173.00
# 6                      1094.800  1152.2250   1178.10
# 7                      1091.475  1139.2125   1201.90
# 8                      1136.250  1145.3625   1173.00
# 9                      1127.425  1187.9250   1242.00
# 10                     1150.050  1164.6000   1178.10
# 11                     1148.725  1162.1250   1215.40
# 12                     1215.400  1237.6000   1237.60
# 13                     1303.875  1321.7500   1357.00
# 14                     1390.500  1404.2000   1485.00
# 15                     1514.500  1582.1000   1602.25
# 16                     1721.250  1724.4375   1772.55
# 17                     1908.900  2936.2500  13668.75

# %%
max(dbscan_opt.labels_)
# Out:
# 16

# %%
df_user['revenueCluster_DBSCAN']=dbscan_opt.labels_
df_user['revenueCluster_DBSCAN'].value_counts()
# Out:
#  0     3069
# -1      528
#  7       14
#  1       10
#  5        9
#  11       9
#  4        8
#  12       8
#  3        7
#  6        7
#  2        6
#  16       6
#  8        6
#  15       6
#  14       6
#  10       6
#  13       6
#  9        5
# Name: revenueCluster_DBSCAN, dtype: int64

# %% [markdown]
# ## Overall Score

# %%
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3716 entries, 0 to 3715
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customerId               3716 non-null   float64
#  1   recency                  3716 non-null   int64
#  2   recencyCluster_Kmeans    3716 non-null   int64
#  3   recencyCluster_DBSCAN    3716 non-null   int64
#  4   frequency                3716 non-null   int64
#  5   frequencyCluster_Kmeans  3716 non-null   int64
#  6   frequencyCluster_DBSCAN  3716 non-null   int64
#  7   revenue_x                3716 non-null   float64
#  8   revenue_y                3716 non-null   float64
#  9   revenueCluster_Kmeans    3716 non-null   int64
#  10  revenueCluster_DBSCAN    3716 non-null   int64
# dtypes: float64(3), int64(8)
# memory usage: 348.4 KB

# %%
# df_user.to_csv('df_user.csv', index=False)

# # If you need to provide a download link in Jupyter Notebook:
# from IPython.display import FileLink
# FileLink(r'df_user.csv')

# %%
# Calculating overallScore by summing the cluster scores
df_user['overallScore'] = (df_user['recencyCluster_Kmeans'] +
                           df_user['frequencyCluster_Kmeans'] +
                           df_user['revenueCluster_Kmeans'] +
                           df_user['recencyCluster_DBSCAN'] +
                           df_user['frequencyCluster_DBSCAN'] +
                           df_user['revenueCluster_DBSCAN'])

# Grouping by overallScore and calculate mean of 'recency', 'frequency', and 'revenue'
df_user.groupby('overallScore')[['recency', 'frequency', 'revenue_x']].mean()  # Assuming revenue_x is the correct revenue column to use
# Out:
#                  recency   frequency    revenue_x
# overallScore
# -2            246.666667   30.666667   750.000000
# -1            300.814815   17.351852   541.116667
#  0            249.646465   23.838384   589.962374
#  1            181.994455   30.670980   723.663808
#  2             83.031881   52.428268   615.614580
#  3             27.264272   99.964721   579.612508
#  4             27.903084  138.167401  1568.703700
#  5             68.014493  217.246377  2469.779275
#  6            158.368421  152.842105  1732.347368
#  7            208.529412  131.294118  2504.580588
#  8            160.000000   78.200000  2081.830000
#  9             87.875000   60.000000  1332.478750
#  10            33.300000  148.500000   370.875000
#  11            54.500000  232.666667  1968.500000
#  12            89.750000  227.000000   355.212500
#  13            56.333333  190.333333   727.980000
#  14             8.000000  364.600000   611.620000
#  15            66.200000  235.100000   497.720000
#  16            54.125000  208.625000   268.546250
#  17            30.333333  142.833333   354.958333
#  18            22.750000  145.125000   330.462500
#  19            19.666667  286.500000   323.606667
#  21            16.000000  715.000000  3351.750000

# %%
print(df_user.describe())

df_user.loc[df_user['overallScore']<=5,'Segment'] = 'Low-Value'
df_user.loc[df_user['overallScore']>5,'Segment'] = 'Mid-Value' 
df_user.loc[df_user['overallScore']>7,'Segment'] = 'High-Value'
# Out:
#          customerId      recency  recencyCluster_Kmeans  \
# count   3716.000000  3716.000000            3716.000000
# mean   15565.514801    82.988428               2.105490
# std     1577.093525    87.115898               1.029399
# min    12346.000000     0.000000               0.000000
# 25%    14209.750000    17.000000               1.000000
# 50%    15589.000000    49.000000               2.000000
# 75%    16935.250000   123.000000               3.000000
# max    18287.000000   338.000000               3.000000
#
#        recencyCluster_DBSCAN    frequency  frequencyCluster_Kmeans  \
# count            3716.000000  3716.000000              3716.000000
# mean                0.047632    79.520990                 0.169268
# std                 0.610489   155.682603                 0.425477
# min                -1.000000     1.000000                 0.000000
# 25%                 0.000000    16.000000                 0.000000
# 50%                 0.000000    38.000000                 0.000000
# 75%                 0.000000    88.000000                 0.000000
# max                 7.000000  4189.000000                 3.000000
#
#        frequencyCluster_DBSCAN     revenue_x     revenue_y  \
# count              3716.000000   3716.000000   3716.000000
# mean                 -0.015608    725.978011    725.978011
# std                   0.177537   1188.701372   1188.701372
# min                  -1.000000      0.000000      0.000000
# 25%                   0.000000    191.100000    191.100000
# 50%                   0.000000    377.550000    377.550000
# 75%                   0.000000    787.650000    787.650000
# max                   2.000000  13668.750000  13668.750000
#
#        revenueCluster_Kmeans  revenueCluster_DBSCAN  overallScore
# count            3716.000000            3716.000000   3716.000000
# mean                0.188105               0.115178      2.610065
# std                 0.472533               1.686994      2.125028
# min                 0.000000              -1.000000     -2.000000
# 25%                 0.000000               0.000000      2.000000
# 50%                 0.000000               0.000000      3.000000
# 75%                 0.000000               0.000000      3.000000
# max                 3.000000              16.000000     21.000000

# %% [markdown]
# ## Clustering Revenue vs Frequency - K-Means

# %%
data_to_cluster = df_user[['revenue_x', 'frequency']]

# Applying K-means clustering on the full dataset with an optimal cluster count
km = KMeans(n_clusters=4, random_state=42)
data_to_cluster['cluster'] = km.fit_predict(data_to_cluster)

# Defining cluster names based on the discussed characteristics
cluster_labels = {0: "Casual", 1: "VIPs", 2: "Regulars", 3: "Big Spenders"}
data_to_cluster['cluster_label'] = data_to_cluster['cluster'].map(cluster_labels)

# Plotting Revenue vs Frequency with cluster coloring and labels
plt.figure(figsize=(10, 6))
scatter = plt.scatter(data_to_cluster['revenue_x'], data_to_cluster['frequency'], 
                      c=data_to_cluster['cluster'], cmap='viridis', alpha=0.5)
plt.title('Revenue vs Frequency - K-means Clustering')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.grid(True)

# Creating a legend with the named clusters
legend_labels = [cluster_labels[i] for i in range(4)]  # List of labels for the legend
legend_handles = scatter.legend_elements()[0]  # Get legend handles
legend1 = plt.legend(legend_handles, legend_labels, title="Clusters")
plt.gca().add_artist(legend1)

plt.show()
# Out:
# C:\Users\eduma\AppData\Local\Temp/ipykernel_21556/2864516618.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_cluster['cluster'] = km.fit_predict(data_to_cluster)
# C:\Users\eduma\AppData\Local\Temp/ipykernel_21556/2864516618.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_cluster['cluster_label'] = data_to_cluster['cluster'].map(cluster_labels)

# %% [markdown]
# ## Clustering Revenue vs Frequency - DBSCAN

# %%
data_to_cluster = df_user[['revenue_x', 'frequency']]
data_to_cluster['cluster'] = df_user['revenueCluster_DBSCAN']

# Defining custom labels for DBSCAN clusters based on the hypothetical understanding of the cluster
# Adjusting these keys based on the actual cluster numbers observed
cluster_labels = {
    -1: "Outliers",  # DBSCAN labels noise as -1
    0: "Sporadic Shoppers",
    1: "Occasional Shoppers",
    2: "Frequent Customers",
    3: "Regular Customers",
    4: "Consistent Customers",
    5: "Loyal Customers",
    6: "Very Loyal Customers",
    7: "Premium Customers",
    8: "Very Premium Customers"
}
data_to_cluster['cluster_label'] = data_to_cluster['cluster'].map(cluster_labels)

# Plotting Revenue vs Frequency with DBSCAN cluster coloring
plt.figure(figsize=(10, 6))
scatter = plt.scatter(data_to_cluster['revenue_x'], data_to_cluster['frequency'], 
                      c=data_to_cluster['cluster'], cmap='Set1', alpha=0.5)
plt.title('Revenue vs Frequency - DBSCAN Clustering')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.grid(True)

# Creating a legend with the named clusters
legend_labels = [cluster_labels.get(i, "Unknown") for i in sorted(data_to_cluster['cluster'].unique())]
legend_handles = scatter.legend_elements()[0]  # Get legend handles
legend1 = plt.legend(legend_handles, legend_labels, title="Clusters")
plt.gca().add_artist(legend1)

plt.show()
# Out:
# C:\Users\eduma\AppData\Local\Temp/ipykernel_21556/1624357831.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_cluster['cluster'] = df_user['revenueCluster_DBSCAN']
# C:\Users\eduma\AppData\Local\Temp/ipykernel_21556/1624357831.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_cluster['cluster_label'] = data_to_cluster['cluster'].map(cluster_labels)

# %% [markdown]
# ## Clustering Revenue vs Recency - K-Means

# %%
cluster_descriptive_mapping = {
    1: "Frequent & High Spenders",
    2: "Recent & Moderate Spenders",
    3: "Inactive & High Spenders",
    4: "Inactive & Low Spenders"
}

# Apply the mapping to the DataFrame
df_user['descriptive_cluster'] = df_user['recencyCluster_Kmeans'].map(cluster_descriptive_mapping)

# Setting up the plot with the new descriptive labels
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_user, x='recency', y='revenue_x', hue='descriptive_cluster', palette='viridis', s=100, alpha=0.7)

# Enhancing the plot
plt.title('Revenue vs Recency', fontsize=16)
plt.xlabel('Recency (days since last purchase)', fontsize=14)
plt.ylabel('Revenue', fontsize=14)
plt.legend(title='Customer Segment', title_fontsize='13', fontsize='12', loc='upper right')
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# ## Clustering Revenue vs Recency - DBSCAN

# %%
plt.figure(figsize=(10, 6))

# Assign more descriptive labels based on cluster IDs and characteristics
descriptive_labels = {
    -1: 'Noise - Outliers',
    0: 'Inactive & Spender',
    1: 'Inactive & Good Spender',
    2: 'Recent & Moderate Spender',
    3: 'Recent & Good Spender',
    4: 'Recent & High Spender',
    5: 'Frequent & Good Spender',
    6: 'Frequent & High Spender',
    7: 'Frequent & Constant Spender'
}

# Create a scatter plot with uniform circle markers
for cluster_id in sorted(df_user['recencyCluster_DBSCAN'].unique()):
    cluster_data = df_user[df_user['recencyCluster_DBSCAN'] == cluster_id]
    label = descriptive_labels.get(cluster_id, f'Cluster {cluster_id}')
    plt.scatter(cluster_data['recency'], cluster_data['revenue_x'], label=label, marker='o', s=100)

# Enhancing the plot
plt.title('Refined Revenue vs Recency (DBSCAN Clustering)', fontsize=16)
plt.xlabel('Recency (days since last purchase)', fontsize=14)
plt.ylabel('Revenue', fontsize=14)
plt.legend(title='DBSCAN Cluster', title_fontsize='13', fontsize='12', loc='upper right')
plt.grid(True)

# Show the refined plot
plt.show()

# %% [markdown]
# ## Clustering Revenue vs Frecency - K-Means

# %%
frequency_cluster_descriptive_mapping = {
    0: "Low Activity",
    1: "Moderate Activity",
    2: "High Activity",
    3: "Very High Activity"
}

# Apply the mapping to the DataFrame
df_user['descriptive_frequency_label'] = df_user['frequencyCluster_Kmeans'].map(frequency_cluster_descriptive_mapping)


# Setting up the plot with uniform circle markers and an easier to distinguish color palette
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_user, x='frequency', y='revenue_x', hue='descriptive_frequency_label', 
                palette='Set2', s=100, style='descriptive_frequency_label', markers=['o']*4, alpha=0.7)

# Enhancing the plot
plt.title('Revenue vs Frequency with Accessible Colors', fontsize=16)
plt.xlabel('Frequency (number of transactions)', fontsize=14)
plt.ylabel('Revenue', fontsize=14)
plt.legend(title='Customer Activity Level', title_fontsize='13', fontsize='12', loc='upper right')
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Clustering Revenue vs Frecency - DBSCAN

# %%
# Assign more descriptive labels based on DBSCAN clustering characteristics
dbscan_frequency_descriptive_labels = {
    -1: 'Outliers - Noise',
    0: 'Low Activity',
    1: 'Moderate Activity',
    2: 'High Activity',
    3: 'Very High Activity'
}

# Map the new descriptive labels to the data
df_user['descriptive_frequency_dbscan_label'] = df_user['frequencyCluster_DBSCAN'].map(dbscan_frequency_descriptive_labels)

# Setting up the plot with descriptive labels
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_user, x='frequency', y='revenue_x', hue='descriptive_frequency_dbscan_label', 
                palette='Set2', s=100, marker='o', alpha=0.7)

# Enhancing the plot
plt.title('Revenue vs Frequency with Descriptive DBSCAN Labels', fontsize=16)
plt.xlabel('Frequency (number of transactions)', fontsize=14)
plt.ylabel('Revenue', fontsize=14)
plt.legend(title='DBSCAN Frequency Cluster', title_fontsize='13', fontsize='12', loc='upper right')
plt.grid(True)

# Show the updated plot
plt.show()

# %% [markdown]
# # References

# %% [markdown]
# Scikit-learn.org. (2017). sklearn.cluster.DBSCAN — scikit-learn 0.22 documentation. [online] Available at: https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html.

# %% [markdown]
# Sharma, A. (2020). How Does DBSCAN Clustering Work? | DBSCAN Clustering for ML. [online] Analytics Vidhya. Available at: https://www.analyticsvidhya.com/blog/2020/09/how-dbscan-clustering-works/.

# %% [markdown]
# GeeksforGeeks. (2010). Print nodes at k distance from root. [online] Available at: https://www.geeksforgeeks.org/print-nodes-at-k-distance-from-root/ [Accessed 10 Apr. 2024].
